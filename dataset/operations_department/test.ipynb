# %%
import pandas as pd

# %%
df = pd.read_csv("line_item_data_prices1.csv", index_col=0)
df.head(2)
# Out:
#                                order_id  price quantity
# 0  8d8acbac-ccbb-4609-a978-98dee3ac3088  12.81      6px
# 1  59e4c308-5262-486d-9f1a-12b1278e3c44  14.00  6pieces
